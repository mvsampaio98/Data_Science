# %% [markdown]
# ### Importando base de dados e visualizando as primeiras linhas:

# %%
import pandas as pd

dados = pd.read_csv('dados/producao.csv', sep=';', encoding='ISO-8859-1')
dados.head()
# Out:
#    id                         produto       1970       1971       1972  \
# 0   1                   VINHO DE MESA  217208604  154264651  146953297
# 1   2                           Tinto  174224052  121133369  118180926
# 2   3                          Branco     748400    1160500    1812367
# 3   4                          Rosado   42236152   31970782   26960004
# 4   5  VINHO FINO DE MESA (VINÃFERA)   23899346   23586062   21078771
#
#         1973       1974       1975       1976       1977  ...       2013  \
# 0  116710345  193875345  177401209  144565438  195359778  ...  196904222
# 1   88589019  146544484  144274134  118360170  154801826  ...  163111797
# 2     243900    4138768    1441507    1871473    4954387  ...   32066403
# 3   27877426   43192093   31685568   24333795   35603565  ...    1726022
# 4   12368410   31644124   39424590   34500590   41264971  ...   45782530
#
#         2014       2015      2016       2017       2018       2019       2020  \
# 0  196173123  210308560  86319015  255015187  218375636  144629737  124200414
# 1  157776363  169811472  75279191    1365957  188270142  121045115  103916391
# 2   37438069   39557250  10727099  217527985   29229970   22032828   19568734
# 3     958691     939838    312725   36121245     875524    1551794     715289
# 4   38464314   37148982  18070626   44537870   38707220   37615422   32516686
#
#         2021       2022
# 0  173899995  195031611
# 1  146075996  162844214
# 2   26432799   30198430
# 3    1391200    1988968
# 4   43474998   47511796
#
# [5 rows x 55 columns]

# %% [markdown]
# ### Checando o tamanho do DataFrame:

# %%
print(f'O tamanho do Dataset é de {dados.shape[0]} linhas e {dados.shape[1]} colunas')
# Out:
# O tamanho do Dataset é de 51 linhas e 55 colunas

# %% [markdown]
# ### Checando os tipos de dados do DataFrame:

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 55 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       51 non-null     int64
#  1   produto  51 non-null     object
#  2   1970     51 non-null     int64
#  3   1971     51 non-null     int64
#  4   1972     51 non-null     int64
#  5   1973     51 non-null     int64
#  6   1974     51 non-null     int64
#  7   1975     51 non-null     int64
#  8   1976     51 non-null     int64
#  9   1977     51 non-null     int64
#  10  1978     51 non-null     int64
#  11  1979     51 non-null     int64
#  12  1980     51 non-null     int64
#  13  1981     51 non-null     int64
#  14  1982     51 non-null     int64
#  15  1983     51 non-null     int64
#  16  1984     51 non-null     int64
#  17  1985     51 non-null     int64
#  18  1986     51 non-null     int64
#  19  1987     51 non-null     int64
#  20  1988     51 non-null     int64
#  21  1989     51 non-null     int64
#  22  1990     51 non-null     int64
#  23  1991     51 non-null     int64
#  24  1992     51 non-null     int64
#  25  1993     51 non-null     int64
#  26  1994     51 non-null     int64
#  27  1995     51 non-null     int64
#  28  1996     51 non-null     int64
#  29  1997     51 non-null     int64
#  30  1998     51 non-null     int64
#  31  1999     51 non-null     int64
#  32  2000     51 non-null     int64
#  33  2001     51 non-null     int64
#  34  2002     51 non-null     int64
#  35  2003     51 non-null     int64
#  36  2004     51 non-null     int64
#  37  2005     51 non-null     int64
#  38  2006     51 non-null     int64
#  39  2007     51 non-null     int64
#  40  2008     51 non-null     int64
#  41  2009     51 non-null     int64
#  42  2010     51 non-null     int64
#  43  2011     51 non-null     int64
#  44  2012     51 non-null     int64
#  45  2013     51 non-null     int64
#  46  2014     51 non-null     int64
#  47  2015     51 non-null     int64
#  48  2016     51 non-null     int64
#  49  2017     51 non-null     int64
#  50  2018     51 non-null     int64
#  51  2019     51 non-null     int64
#  52  2020     51 non-null     int64
#  53  2021     51 non-null     int64
#  54  2022     51 non-null     int64
# dtypes: int64(54), object(1)
# memory usage: 22.0+ KB

# %% [markdown]
# ### Dropar a coluna ID:

# %%
dados_gerais = dados.drop('id', axis=1)
dados_gerais.head()
# Out:
#                           produto       1970       1971       1972       1973  \
# 0                   VINHO DE MESA  217208604  154264651  146953297  116710345
# 1                           Tinto  174224052  121133369  118180926   88589019
# 2                          Branco     748400    1160500    1812367     243900
# 3                          Rosado   42236152   31970782   26960004   27877426
# 4  VINHO FINO DE MESA (VINÃFERA)   23899346   23586062   21078771   12368410
#
#         1974       1975       1976       1977       1978  ...       2013  \
# 0  193875345  177401209  144565438  195359778  200053669  ...  196904222
# 1  146544484  144274134  118360170  154801826  162917363  ...  163111797
# 2    4138768    1441507    1871473    4954387    5079748  ...   32066403
# 3   43192093   31685568   24333795   35603565   32056558  ...    1726022
# 4   31644124   39424590   34500590   41264971   36750933  ...   45782530
#
#         2014       2015      2016       2017       2018       2019       2020  \
# 0  196173123  210308560  86319015  255015187  218375636  144629737  124200414
# 1  157776363  169811472  75279191    1365957  188270142  121045115  103916391
# 2   37438069   39557250  10727099  217527985   29229970   22032828   19568734
# 3     958691     939838    312725   36121245     875524    1551794     715289
# 4   38464314   37148982  18070626   44537870   38707220   37615422   32516686
#
#         2021       2022
# 0  173899995  195031611
# 1  146075996  162844214
# 2   26432799   30198430
# 3    1391200    1988968
# 4   43474998   47511796
#
# [5 rows x 54 columns]

# %% [markdown]
# ### Checar a coluna produto:

# %%
dados_gerais['produto']
# Out:
# 0                                  VINHO DE MESA
# 1                                          Tinto
# 2                                         Branco
# 3                                         Rosado
# 4                 VINHO FINO DE MESA (VINÃFERA)
# 5                                          Tinto
# 6                                         Branco
# 7                                         Rosado
# 8                                           SUCO
# 9                           Suco de uva integral
# 10                       Suco de uva concentrado
# 11                          Suco de uva adoÃ§ado
# 12                         Suco de uva orgÃ¢nico
# 13                    Suco de uva reconstituÃ­do
# 14                                     DERIVADOS
# 15                                     Espumante
# 16                            Espumante moscatel
# 17                                Base espumante
# 18                       Base espumante moscatel
# 19                    Base Champenoise champanha
# 20                        Base Charmat champanha
# 21                                 Bebida de uva
# 22                                  Polpa de uva
# 23                                 Mosto simples
# 24                             Mosto concentrado
# 25                      Mosto de uva com bagaÃ§o
# 26                            Mosto dessulfitado
# 27                                      Mistelas
# 28                                NÃ©ctar de uva
# 29                                     Licorosos
# 30                                     Compostos
# 31                                      Jeropiga
# 32                                      Filtrado
# 33                                      Frisante
# 34                                    Vinho leve
# 35                                Vinho licoroso
# 36                                        Brandy
# 37                                     Destilado
# 38                                     Bagaceira
# 39                            Licor de bagaceira
# 40                                       Vinagre
# 41                                Borra lÃ­quida
# 42                                    Borra seca
# 43                                Vinho Composto
# 44                                         Pisco
# 45                               Vinho orgÃ¢nico
# 46                           Espumante orgÃ¢nico
# 47    Destilado alcoÃ³lico simples de bagaceira
# 48                            Vinho acidificado
# 49                Mosto parcialmente fermentado
# 50                              Outros derivados
# Name: produto, dtype: object

# %% [markdown]
# ### Filtrando o DataFrame apenas com os dados gerais e desprezando as subcategorias nesse momento:

# %%
dados_gerais = dados_gerais.query('(produto == "VINHO DE MESA") | (produto == "VINHO FINO DE MESA (VINÃFERA)") | (produto == "SUCO") | (produto == "DERIVADOS")')
dados_gerais = dados_gerais.reset_index(drop=True)
dados_gerais
# Out:
#                           produto       1970       1971       1972       1973  \
# 0                   VINHO DE MESA  217208604  154264651  146953297  116710345
# 1  VINHO FINO DE MESA (VINÃFERA)   23899346   23586062   21078771   12368410
# 2                            SUCO    1097771    2296654    3509440          0
# 3                       DERIVADOS   14164329   13280518   12314509   28317919
#
#         1974       1975       1976       1977       1978  ...       2013  \
# 0  193875345  177401209  144565438  195359778  200053669  ...  196904222
# 1   31644124   39424590   34500590   41264971   36750933  ...   45782530
# 2          0          0          0          0          0  ...   64879790
# 3   47904934   53633143   22925012   24015856   41607777  ...   64072127
#
#         2014       2015      2016       2017       2018       2019       2020  \
# 0  196173123  210308560  86319015  255015187  218375636  144629737  124200414
# 1   38464314   37148982  18070626   44537870   38707220   37615422   32516686
# 2   76723537   87894468  42210389   77161971   65467906   77805352   69261287
# 3   62907281  107349704  53950314  109116761   95202101  142888747   92533804
#
#         2021       2022
# 0  173899995  195031611
# 1   43474998   47511796
# 2  100932264   65809079
# 3  169031493  138501226
#
# [4 rows x 54 columns]

# %% [markdown]
# ### Definindo produto como Index:

# %%
dados_gerais = dados_gerais.set_index('produto')
dados_gerais
# Out:
#                                      1970       1971       1972       1973  \
# produto
# VINHO DE MESA                   217208604  154264651  146953297  116710345
# VINHO FINO DE MESA (VINÃFERA)   23899346   23586062   21078771   12368410
# SUCO                              1097771    2296654    3509440          0
# DERIVADOS                        14164329   13280518   12314509   28317919
#
#                                      1974       1975       1976       1977  \
# produto
# VINHO DE MESA                   193875345  177401209  144565438  195359778
# VINHO FINO DE MESA (VINÃFERA)   31644124   39424590   34500590   41264971
# SUCO                                    0          0          0          0
# DERIVADOS                        47904934   53633143   22925012   24015856
#
#                                      1978       1979  ...       2013  \
# produto                                               ...
# VINHO DE MESA                   200053669  211252982  ...  196904222
# VINHO FINO DE MESA (VINÃFERA)   36750933   46129710  ...   45782530
# SUCO                                    0          0  ...   64879790
# DERIVADOS                        41607777   35370846  ...   64072127
#
#                                      2014       2015      2016       2017  \
# produto
# VINHO DE MESA                   196173123  210308560  86319015  255015187
# VINHO FINO DE MESA (VINÃFERA)   38464314   37148982  18070626   44537870
# SUCO                             76723537   87894468  42210389   77161971
# DERIVADOS                        62907281  107349704  53950314  109116761
#
#                                      2018       2019       2020       2021  \
# produto
# VINHO DE MESA                   218375636  144629737  124200414  173899995
# VINHO FINO DE MESA (VINÃFERA)   38707220   37615422   32516686   43474998
# SUCO                             65467906   77805352   69261287  100932264
# DERIVADOS                        95202101  142888747   92533804  169031493
#
#                                      2022
# produto
# VINHO DE MESA                   195031611
# VINHO FINO DE MESA (VINÃFERA)   47511796
# SUCO                             65809079
# DERIVADOS                       138501226
#
# [4 rows x 53 columns]

# %% [markdown]
# ### Renomeando o Indice:

# %%
dados_gerais.index = ['VINHO DE MESA', 'VINHO FINO DE MESA', 'SUCO', 'DERIVADOS']
dados_gerais
# Out:
#                          1970       1971       1972       1973       1974  \
# VINHO DE MESA       217208604  154264651  146953297  116710345  193875345
# VINHO FINO DE MESA   23899346   23586062   21078771   12368410   31644124
# SUCO                  1097771    2296654    3509440          0          0
# DERIVADOS            14164329   13280518   12314509   28317919   47904934
#
#                          1975       1976       1977       1978       1979  \
# VINHO DE MESA       177401209  144565438  195359778  200053669  211252982
# VINHO FINO DE MESA   39424590   34500590   41264971   36750933   46129710
# SUCO                        0          0          0          0          0
# DERIVADOS            53633143   22925012   24015856   41607777   35370846
#
#                     ...       2013       2014       2015      2016       2017  \
# VINHO DE MESA       ...  196904222  196173123  210308560  86319015  255015187
# VINHO FINO DE MESA  ...   45782530   38464314   37148982  18070626   44537870
# SUCO                ...   64879790   76723537   87894468  42210389   77161971
# DERIVADOS           ...   64072127   62907281  107349704  53950314  109116761
#
#                          2018       2019       2020       2021       2022
# VINHO DE MESA       218375636  144629737  124200414  173899995  195031611
# VINHO FINO DE MESA   38707220   37615422   32516686   43474998   47511796
# SUCO                 65467906   77805352   69261287  100932264   65809079
# DERIVADOS            95202101  142888747   92533804  169031493  138501226
#
# [4 rows x 53 columns]

# %% [markdown]
# ### Primeiras visualizações:

# %%
import matplotlib.pyplot as plt
import numpy as np

dados_gerais_milhares = dados_gerais / 1000000
dados_gerais_milhares.T.loc['2007':].plot(figsize=(12,6))
plt.xticks(np.arange(0, 16, step=1),labels=dados_gerais_milhares.T.loc['2007':].index)
plt.title('Produção em Milhões de Litros de produtos feitos com uva')
plt.ylabel('Milhões de Litros')
plt.grid()
plt.show()

# %% [markdown]
# **Por que houve uma queda de produção brusca no ano de 2016 ?**

# %% [markdown]
# Segundo essa [fonte](https://www.embrapa.br/busca-de-noticias/-/noticia/9103859/artigo-safra-da-uva-2016----o-que-esta-acontecendo) ocorreu o seguinte:
#
# **Eventos de granizo, geadas e o excesso de chuvas, determinado pelo fenômeno climático El Niño, têm causado uma perda significativa na produtividade dos vinhedos em todas as áreas produtoras de uvas do RS. Tudo começou com um inverno de temperaturas amenas(30 a 40% de horas de frio, comparado com o normal), fazendo brotar menos ramos nas videiras.**

# %% [markdown]
# --------------

# %% [markdown]
# ### Pegando os dados de 2007 sobre aspectos gerais do clima de Porto Alegre - RS

# %%
dados_imet_rs = pd.read_csv('dados/INMET_S_RS_A801_PORTO ALEGRE_2007.csv', encoding='ISO-8859-1', sep=';',skiprows=8)
dados_imet_rs
# Out:
#      DATA (YYYY-MM-DD) HORA (UTC) PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0           2007-01-01      00:00                                0
# 1           2007-01-01      01:00                                0
# 2           2007-01-01      02:00                                0
# 3           2007-01-01      03:00                                0
# 4           2007-01-01      04:00                                0
# ...                ...        ...                              ...
# 8755        2007-12-31      19:00                                0
# 8756        2007-12-31      20:00                                0
# 8757        2007-12-31      21:00                                0
# 8758        2007-12-31      22:00                                0
# 8759        2007-12-31      23:00                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                1008,2
# 1                                                1008,3
# 2                                                1008,4
# 3                                                  1008
# 4                                                1007,6
# ...                                                 ...
# 8755                                             1004,9
# 8756                                             1004,7
# 8757                                             1004,7
# 8758                                             1005,2
# 8759                                             1005,9
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                             1008,2
# 1                                             1008,4
# 2                                             1008,5
# 3                                             1008,4
# 4                                               1008
# ...                                              ...
# 8755                                          1005,6
# 8756                                            1005
# 8757                                          1004,7
# 8758                                          1005,2
# 8759                                          1005,9
#
#      PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (KJ/m²)  \
# 0                                              1007,9                   -9999
# 1                                              1008,2                   -9999
# 2                                              1008,3                   -9999
# 3                                                1008                   -9999
# 4                                              1007,6                   -9999
# ...                                               ...                     ...
# 8755                                           1004,9                  2765,1
# 8756                                           1004,7                  2012,7
# 8757                                           1004,5                  1307,6
# 8758                                           1004,7                   329,1
# 8759                                           1005,2                    13,3
#
#      TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                            24,9
# 1                                            23,8
# 2                                            23,3
# 3                                            23,5
# 4                                            23,3
# ...                                           ...
# 8755                                         31,4
# 8756                                         31,3
# 8757                                         30,1
# 8758                                         27,7
# 8759                                           26
#
#      TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                    20,1
# 1                                    20,4
# 2                                    20,6
# 3                                    20,6
# 4                                    20,6
# ...                                   ...
# 8755                                 17,9
# 8756                                 18,5
# 8757                                 18,3
# 8758                                 19,7
# 8759                                 20,7
#
#      TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 0                                          26,5
# 1                                          24,9
# 2                                          23,8
# 3                                          23,6
# 4                                          23,6
# ...                                         ...
# 8755                                       31,8
# 8756                                       31,4
# 8757                                       31,3
# 8758                                       30,1
# 8759                                       27,7
#
#      TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 0                                          24,9
# 1                                          23,8
# 2                                          23,2
# 3                                          23,1
# 4                                          23,2
# ...                                         ...
# 8755                                       30,9
# 8756                                       30,5
# 8757                                       30,1
# 8758                                       27,7
# 8759                                         26
#
#      TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 0                                                20,8
# 1                                                20,4
# 2                                                20,6
# 3                                                20,7
# 4                                                20,7
# ...                                               ...
# 8755                                             20,9
# 8756                                               19
# 8757                                             19,1
# 8758                                             19,9
# 8759                                             20,9
#
#      TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 0                                                20,1
# 1                                                  20
# 2                                                20,4
# 3                                                20,6
# 4                                                20,6
# ...                                               ...
# 8755                                             17,9
# 8756                                             16,2
# 8757                                             17,6
# 8758                                             18,4
# 8759                                             19,8
#
#       UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                           75
# 1                                           81
# 2                                           85
# 3                                           86
# 4                                           85
# ...                                        ...
# 8755                                        54
# 8756                                        48
# 8757                                        52
# 8758                                        62
# 8759                                        73
#
#       UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                           71
# 1                                           74
# 2                                           81
# 3                                           84
# 4                                           84
# ...                                        ...
# 8755                                        45
# 8756                                        40
# 8757                                        44
# 8758                                        49
# 8759                                        62
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 0                                      75
# 1                                      81
# 2                                      85
# 3                                      84
# 4                                      85
# ...                                   ...
# 8755                                   45
# 8756                                   47
# 8757                                   49
# 8758                                   62
# 8759                                   73
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr)) VENTO, RAJADA MAXIMA (m/s)  \
# 0                                      114                        4,5
# 1                                      121                        6,2
# 2                                      117                        4,9
# 3                                       80                        3,2
# 4                                       82                        2,8
# ...                                    ...                        ...
# 8755                                   152                          6
# 8756                                   153                        7,1
# 8757                                   141                        6,4
# 8758                                   134                        6,2
# 8759                                    95                          6
#
#      VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 0                                1,9          NaN
# 1                                1,9          NaN
# 2                                1,2          NaN
# 3                                 ,8          NaN
# 4                                 ,8          NaN
# ...                              ...          ...
# 8755                             2,1          NaN
# 8756                             2,5          NaN
# 8757                             2,1          NaN
# 8758                             2,8          NaN
# 8759                             1,4          NaN
#
# [8760 rows x 20 columns]

# %% [markdown]
# ---------------

# %% [markdown]
# ### Analisando a coluna precipitação total (Que indica as chuvas):

# %%
dados_imet_rs['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'].unique()
# Out:
# array(['0', '1,2', '7,4', '1,8', ',2', '1', ',4', '10,4', ',8', '1,6',
#        '8,8', '7,2', '2,8', '5', '3,2', '2,2', '5,2', '9,8', '2', '4',
#        '2,4', '2,6', '1,4', ',6', '8,2', '4,6', '13,2', '4,2', '40,6',
#        '3,6', '3,4', '-9999', '3,8', '9,6', '4,8', '9,4', '3', '5,8',
#        '14,6', '8,4', '11', '4,4', '16', '5,4', '15,2', '21,2', '8', '6',
#        '6,8', '7,8', '10,2', '5,6', '7,6', '6,6', '17,8', '16,8', '16,6'],
#       dtype=object)

# %% [markdown]
# ### Fazendo substituição de "," para "." com intuito de transformar a coluna em float:

# %%
dados_imet_rs['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'] = dados_imet_rs['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'].str.replace(',','.')
dados_imet_rs['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'].unique()
# Out:
# array(['0', '1.2', '7.4', '1.8', '.2', '1', '.4', '10.4', '.8', '1.6',
#        '8.8', '7.2', '2.8', '5', '3.2', '2.2', '5.2', '9.8', '2', '4',
#        '2.4', '2.6', '1.4', '.6', '8.2', '4.6', '13.2', '4.2', '40.6',
#        '3.6', '3.4', '-9999', '3.8', '9.6', '4.8', '9.4', '3', '5.8',
#        '14.6', '8.4', '11', '4.4', '16', '5.4', '15.2', '21.2', '8', '6',
#        '6.8', '7.8', '10.2', '5.6', '7.6', '6.6', '17.8', '16.8', '16.6'],
#       dtype=object)

# %% [markdown]
# ### Transformando coluna em float:

# %%
dados_imet_rs['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'] = dados_imet_rs['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'].astype('float')

# %% [markdown]
# ### Excluindo possível outlier "-9999":

# %%
dados_imet_rs = dados_imet_rs[dados_imet_rs['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'] >= 0]

# %%
dados_imet_rs['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'].unique()
# Out:
# array([ 0. ,  1.2,  7.4,  1.8,  0.2,  1. ,  0.4, 10.4,  0.8,  1.6,  8.8,
#         7.2,  2.8,  5. ,  3.2,  2.2,  5.2,  9.8,  2. ,  4. ,  2.4,  2.6,
#         1.4,  0.6,  8.2,  4.6, 13.2,  4.2, 40.6,  3.6,  3.4,  3.8,  9.6,
#         4.8,  9.4,  3. ,  5.8, 14.6,  8.4, 11. ,  4.4, 16. ,  5.4, 15.2,
#        21.2,  8. ,  6. ,  6.8,  7.8, 10.2,  5.6,  7.6,  6.6, 17.8, 16.8,
#        16.6])

# %% [markdown]
# ### A precipitação total no ano de 2007 foi de:

# %%
dados_imet_rs['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'].sum()
# Out:
# 1501.0

# %% [markdown]
# -----------

# %% [markdown]
# ### Vamos analisar também a coluna de umidade, pois se a umidade é maior mais possibilidade de haver pragas nos vinhedos:

# %% [markdown]
# Verificando possiveis presenças de outliers:

# %%
dados_imet_rs['UMIDADE RELATIVA DO AR, HORARIA (%)'].unique()
# Out:
# array([75, 81, 85, 84, 87, 86, 88, 89, 71, 58, 55, 47, 45, 43, 40, 37, 39,
#        50, 53, 68, 73, 72, 74, 70, 67, 69, 66, 57, 51, 46, 44, 52, 61, 77,
#        78, 80, 82, 79, 76, 63, 54, 62, 93, 92, 91, 90, 60, 56, 83, 64, 65,
#        49, 59, 48, 94, 42, 36, 35, 33, 41, 32, 29, 31, 34, 38, 30, 27, 26,
#        25, 95, 96, 28, 24, 22, 23], dtype=int64)

# %% [markdown]
# Tirando a média da umidade anual:

# %%
dados_imet_rs['UMIDADE RELATIVA DO AR, HORARIA (%)'].mean()
# Out:
# 74.90882828749712

# %% [markdown]
# ### Agora precisamos obter os valores entre 2007-2022:

# %%
def tratar_dados_imet():
    dados_imet_rs_prec_lista = []
    dados_imet_rs_umd_lista = []
    for i in range(0,16):
        dados_imet_rs = pd.read_csv(f'dados/INMET_S_RS_A801_PORTO ALEGRE_{2007+i}.csv', encoding='ISO-8859-1', sep=';',skiprows=8)
        dados_imet_rs['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'] = dados_imet_rs['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'].str.replace(',','.')
        dados_imet_rs['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'] = dados_imet_rs['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'].astype('float')
        dados_imet_rs = dados_imet_rs[dados_imet_rs['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'] >= 0]
        dados_imet_rs_prec_lista.append(dados_imet_rs['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'].sum())
        dados_imet_rs_umd_lista.append(dados_imet_rs['UMIDADE RELATIVA DO AR, HORARIA (%)'].mean())
    return dados_imet_rs_prec_lista, dados_imet_rs_umd_lista

# %% [markdown]
# ### Obtendo todas as somas de precipitação entre 2007 e 2022 em Porto Alegre:

# %%
dados_imet_rs_listas = tratar_dados_imet()
dados_imet_rs_listas
# Out:
# ([1501.0,
#   1518.8000000000002,
#   1737.6,
#   1481.4,
#   1299.6,
#   1394.3999999999999,
#   1381.1999999999998,
#   1787.4,
#   1853.1999999999998,
#   1561.3999999999999,
#   1756.6000000000001,
#   1446.6,
#   1542.7999999999997,
#   1425.2,
#   1221.0,
#   1316.9999999999998],
#  [74.90882828749712,
#   74.64165212332752,
#   73.30712896212381,
#   73.44731428571428,
#   76.23918516823072,
#   73.43906605922551,
#   75.40215502259298,
#   77.02356979405035,
#   79.29270523667962,
#   78.79729260673378,
#   79.1550814406974,
#   80.30623430006851,
#   77.7235354573484,
#   74.33564920273348,
#   75.31041642634675,
#   76.74398625429554])

# %% [markdown]
# ### Criando um DataFrame:

# %%
dic_imet = {'Ano': np.arange(2007,2023), 'Precipitacao_Total': dados_imet_rs_listas[0], 'Umidade_Media_%': dados_imet_rs_listas[1]}
df_imet_tratado = pd.DataFrame(data = dic_imet)
df_imet_tratado
# Out:
#      Ano  Precipitacao_Total  Umidade_Media_%
# 0   2007              1501.0        74.908828
# 1   2008              1518.8        74.641652
# 2   2009              1737.6        73.307129
# 3   2010              1481.4        73.447314
# 4   2011              1299.6        76.239185
# 5   2012              1394.4        73.439066
# 6   2013              1381.2        75.402155
# 7   2014              1787.4        77.023570
# 8   2015              1853.2        79.292705
# 9   2016              1561.4        78.797293
# 10  2017              1756.6        79.155081
# 11  2018              1446.6        80.306234
# 12  2019              1542.8        77.723535
# 13  2020              1425.2        74.335649
# 14  2021              1221.0        75.310416
# 15  2022              1317.0        76.743986

# %% [markdown]
# ### Visualizando a precipitação em um gráfico de barras:

# %%
import seaborn as sns

plt.figure(figsize=(12,6))
plt.grid(True)
sns.barplot(data=df_imet_tratado, x='Ano', y='Precipitacao_Total')
plt.axhline(df_imet_tratado['Precipitacao_Total'].mean(), color='r')
plt.title('Precipitação Total (mm) por ano')
plt.xlabel(' ')
plt.ylabel(' ')
plt.show()

# %% [markdown]
# Consegui notar uma precitação auge no período de  2014 e 2015, que pode ter influenciado diretamente na produção de vinhos e derivados no ano de 2016, e por isso pode ter acontecido um queda brusca de produção no ano de 2016

# %% [markdown]
# ### Visualizando a umidade em um gráfico de barras:

# %%
import seaborn as sns

plt.figure(figsize=(12,6))
plt.grid(True)
plt.title('Porcentagem de Umidade média por ano')
plt.xlabel(' ')
plt.ylabel(' ')
sns.barplot(data=df_imet_tratado, x='Ano', y='Umidade_Media_%')
plt.axhline(df_imet_tratado['Umidade_Media_%'].mean(), color='r')
plt.show()

# %% [markdown]
# Nesse gráfico esperava ver uma maior umidade nos anos de 2015 e 2016, a umidade interfere diretamente na proliferação de pragas e no nascimento dos vinhedos. Entretanto, parece se manter constante e não consegui extrair mais insights sobre esse ponto.

# %% [markdown]
# -----------

# %% [markdown]
# ### Partindo para análise das sub-categorias:

# %%
df_vinho_mesa = dados.drop('id', axis = 1)
df_vinho_mesa = df_vinho_mesa[1:4]
df_vinho_mesa = df_vinho_mesa.reset_index(drop=True)
df_vinho_mesa = df_vinho_mesa.set_index('produto')
df_vinho_mesa
# Out:
#               1970       1971       1972      1973       1974       1975  \
# produto
# Tinto    174224052  121133369  118180926  88589019  146544484  144274134
# Branco      748400    1160500    1812367    243900    4138768    1441507
# Rosado    42236152   31970782   26960004  27877426   43192093   31685568
#
#               1976       1977       1978       1979  ...       2013  \
# produto                                              ...
# Tinto    118360170  154801826  162917363  154736439  ...  163111797
# Branco     1871473    4954387    5079748    7146395  ...   32066403
# Rosado    24333795   35603565   32056558   49370148  ...    1726022
#
#               2014       2015      2016       2017       2018       2019  \
# produto
# Tinto    157776363  169811472  75279191    1365957  188270142  121045115
# Branco    37438069   39557250  10727099  217527985   29229970   22032828
# Rosado      958691     939838    312725   36121245     875524    1551794
#
#               2020       2021       2022
# produto
# Tinto    103916391  146075996  162844214
# Branco    19568734   26432799   30198430
# Rosado      715289    1391200    1988968
#
# [3 rows x 53 columns]

# %% [markdown]
# ### Plotando gráfico de vinhos de mesa por categoria nos últimos 15 anos:

# %%
df_vinho_mesa_milhares = df_vinho_mesa / 1000000
df_vinho_mesa_milhares.T.loc['2007':].plot(figsize=(12,6))
plt.xticks(np.arange(0, 16, step=1),labels=df_vinho_mesa_milhares.T.loc['2007':].index)
plt.title('Produção em Milhões de Litros de diferentes tipos de Vinhos de Mesa por ano')
plt.ylabel('Milhões de Litros')
plt.grid()
plt.show()

# %% [markdown]
# **Insights**: Por que no ano de 2017 houve uma acentuada queda de produção dos vinhos tintos e um aumento grande nos vinhos de mesa do tipo Rosado e do tipo Branco ?

# %% [markdown]
# Não tem justificativa, me parece que o dataset está incorreto, pois vendo o [comunicado técnico do ano de 2017]( https://ainfo.cnptia.embrapa.br/digital/bitstream/item/187913/1/Comunicado-Tecnico-207.pdf), os dados foram trocados:
#
# • O valor do Vinho Tinto deveria ser o que está no Vinho Branco;
#
# • O Valor do Vinho Branco deveria ser o que está no Vinho Rosado;
#
# • O Valor do Vinho Rosado deveria ser o que está no Vinho Tinto;

# %%
df_vinho_mesa_milhares['2017'][0] = 217.527985
df_vinho_mesa_milhares['2017'][1] = 36.121245
df_vinho_mesa_milhares['2017'][2] = 1.365957
df_vinho_mesa_milhares
# Out:
#                1970        1971        1972       1973        1974  \
# produto
# Tinto    174.224052  121.133369  118.180926  88.589019  146.544484
# Branco     0.748400    1.160500    1.812367   0.243900    4.138768
# Rosado    42.236152   31.970782   26.960004  27.877426   43.192093
#
#                1975        1976        1977        1978        1979  ...  \
# produto                                                              ...
# Tinto    144.274134  118.360170  154.801826  162.917363  154.736439  ...
# Branco     1.441507    1.871473    4.954387    5.079748    7.146395  ...
# Rosado    31.685568   24.333795   35.603565   32.056558   49.370148  ...
#
#                2013        2014        2015       2016        2017  \
# produto
# Tinto    163.111797  157.776363  169.811472  75.279191  217.527985
# Branco    32.066403   37.438069   39.557250  10.727099   36.121245
# Rosado     1.726022    0.958691    0.939838   0.312725    1.365957
#
#                2018        2019        2020        2021        2022
# produto
# Tinto    188.270142  121.045115  103.916391  146.075996  162.844214
# Branco    29.229970   22.032828   19.568734   26.432799   30.198430
# Rosado     0.875524    1.551794    0.715289    1.391200    1.988968
#
# [3 rows x 53 columns]

# %% [markdown]
# Vendo o gráfico corretamente agora:

# %%
df_vinho_mesa_milhares.T.loc['2007':].plot(figsize=(12,6))
plt.xticks(np.arange(0, 16, step=1),labels=df_vinho_mesa_milhares.T.loc['2007':].index)
plt.title('Produção em Milhões de Litros de diferentes tipos de Vinhos de Mesa por ano')
plt.ylabel('Milhões de Litros')
plt.grid()
plt.show()
